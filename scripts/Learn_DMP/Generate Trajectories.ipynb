# %%
import numpy as npy
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Hello

# %%
acc = npy.load("acceleration.npy")
vel = npy.load("velocity.npy")
pos = npy.load("position.npy")

# %%
tr = npy.linspace(0,99,100)
plt.plot(tr,10*acc,'b')
plt.plot(tr,vel,'r')
plt.show()

# %%
vel2 = npy.zeros((100,2))
dt = 1
for t in range(100):
    vel2[t] = vel2[t-1]+acc[t]*t/5

# %%
acc = 0.1*(npy.random.rand(100,2)-0.5)

# %%
vel = npy.zeros((100,2))
pos = npy.zeros((100,2))

dt = 1
for t in range(0,100):
    vel[t] = vel[t-1] + acc[t]*dt

for t in range(1,100):
    pos[t] = pos[t-1] + vel[t]*dt #+ 0.5*acc[t]*(dt**2)

plt.plot(pos[:,0],pos[:,1])
plt.show()

# %%
plt.plot(tr,acc,'r')
plt.plot(tr,vel,'b')
plt.show()

# %%
pos = npy.zeros((100,2))

for t in range(100):
    pos[t,0] = math.cos(float(t)/20)
    pos[t,1] = math.sin(float(t)/20)

# %%
plt.plot(pos[:,0],pos[:,1])
plt.show()

# %%
# vel = npy.zeros((100,2))
# vel[1:100] = npy.diff(pos,axis=0)
vel = npy.diff(pos,axis=0)

# %%
# acc = npy.zeros((100,2))
# acc[1:100] = npy.diff(vel,axis=0)
acc = npy.diff(vel,axis=0)

# %%
acc
# Out:
# array([[ -2.49635551e-03,  -1.24921895e-04],
#        [ -2.48699223e-03,  -2.49531549e-04],
#        [ -2.47141275e-03,  -3.73517505e-04],
#        [ -2.44965604e-03,  -4.96569862e-04],
#        [ -2.42177645e-03,  -6.18381053e-04],
#        [ -2.38784369e-03,  -7.38646613e-04],
#        [ -2.34794257e-03,  -8.57065941e-04],
#        [ -2.30217281e-03,  -9.73343051e-04],
#        [ -2.25064881e-03,  -1.08718731e-03],
#        [ -2.19349937e-03,  -1.19831417e-03],
#        [ -2.13086732e-03,  -1.30644586e-03],
#        [ -2.06290921e-03,  -1.41131212e-03],
#        [ -1.98979490e-03,  -1.51265084e-03],
#        [ -1.91170715e-03,  -1.61020872e-03],
#        [ -1.82884112e-03,  -1.70374191e-03],
#        [ -1.74140394e-03,  -1.79301664e-03],
#        [ -1.64961415e-03,  -1.87780975e-03],
#        [ -1.55370119e-03,  -1.95790933e-03],
#        [ -1.45390479e-03,  -2.03311514e-03],
#        [ -1.35047438e-03,  -2.10323923e-03],
#        [ -1.24366849e-03,  -2.16810632e-03],
#        [ -1.13375408e-03,  -2.22755427e-03],
#        [ -1.02100587e-03,  -2.28143449e-03],
#        [ -9.05705674e-04,  -2.32961232e-03],
#        [ -7.88141689e-04,  -2.37196733e-03],
#        [ -6.68607761e-04,  -2.40839365e-03],
#        [ -5.47402661e-04,  -2.43880025e-03],
#        [ -4.24829340e-04,  -2.46311111e-03],
#        [ -3.01194167e-04,  -2.48126548e-03],
#        [ -1.76806165e-04,  -2.49321798e-03],
#        [ -5.19762398e-05,  -2.49893873e-03],
#        [  7.29835989e-05,  -2.49841344e-03],
#        [  1.97761017e-04,  -2.49164341e-03],
#        [  3.22044135e-04,  -2.47864558e-03],
#        [  4.45522310e-04,  -2.45945242e-03],
#        [  5.67886912e-04,  -2.43411191e-03],
#        [  6.88832092e-04,  -2.40268738e-03],
#        [  8.08055551e-04,  -2.36525740e-03],
#        [  9.25259292e-04,  -2.32191549e-03],
#        [  1.04015037e-03,  -2.27277001e-03],
#        [  1.15244161e-03,  -2.21794379e-03],
#        [  1.26185234e-03,  -2.15757387e-03],
#        [  1.36810911e-03,  -2.09181113e-03],
#        [  1.47094631e-03,  -2.02081995e-03],
#        [  1.57010691e-03,  -1.94477778e-03],
#        [  1.66534306e-03,  -1.86387467e-03],
#        [  1.75641673e-03,  -1.77831285e-03],
#        [  1.84310026e-03,  -1.68830618e-03],
#        [  1.92517701e-03,  -1.59407961e-03],
#        [  2.00244181e-03,  -1.49586868e-03],
#        [  2.07470155e-03,  -1.39391886e-03],
#        [  2.14177562e-03,  -1.28848496e-03],
#        [  2.20349637e-03,  -1.17983052e-03],
#        [  2.25970952e-03,  -1.06822713e-03],
#        [  2.31027458e-03,  -9.53953715e-04],
#        [  2.35506515e-03,  -8.37295917e-04],
#        [  2.39396929e-03,  -7.18545315e-04],
#        [  2.42688975e-03,  -5.97998724e-04],
#        [  2.45374425e-03,  -4.75957448e-04],
#        [  2.47446566e-03,  -3.52726526e-04],
#        [  2.48900220e-03,  -2.28613972e-04],
#        [  2.49731754e-03,  -1.03930001e-04],
#        [  2.49939087e-03,   2.10137400e-05],
#        [  2.49521704e-03,   1.45904958e-04],
#        [  2.48480646e-03,   2.70431489e-04],
#        [  2.46818516e-03,   3.94282083e-04],
#        [  2.44539468e-03,   5.17147177e-04],
#        [  2.41649198e-03,   6.38719672e-04],
#        [  2.38154932e-03,   7.58695700e-04],
#        [  2.34065402e-03,   8.76775385e-04],
#        [  2.29390831e-03,   9.92663587e-04],
#        [  2.24142902e-03,   1.10607065e-03],
#        [  2.18334732e-03,   1.21671311e-03],
#        [  2.11980840e-03,   1.32431442e-03],
#        [  2.05097105e-03,   1.42860563e-03],
#        [  1.97700735e-03,   1.52932608e-03],
#        [  1.89810216e-03,   1.62622400e-03],
#        [  1.81445270e-03,   1.71905722e-03],
#        [  1.72626806e-03,   1.80759368e-03],
#        [  1.63376864e-03,   1.89161210e-03],
#        [  1.53718565e-03,   1.97090248e-03],
#        [  1.43676050e-03,   2.04526663e-03],
#        [  1.33274420e-03,   2.11451867e-03],
#        [  1.22539673e-03,   2.17848552e-03],
#        [  1.11498641e-03,   2.23700729e-03],
#        [  1.00178920e-03,   2.28993771e-03],
#        [  8.86088038e-04,   2.33714448e-03],
#        [  7.68172119e-04,   2.37850960e-03],
#        [  6.48336170e-04,   2.41392969e-03],
#        [  5.26879718e-04,   2.44331621e-03],
#        [  4.04106342e-04,   2.46659571e-03],
#        [  2.80322909e-04,   2.48371000e-03],
#        [  1.55838816e-04,   2.49461632e-03],
#        [  3.09652068e-05,   2.49928739e-03],
#        [ -9.39857994e-05,   2.49771155e-03],
#        [ -2.18701890e-04,   2.48989273e-03],
#        [ -3.42871340e-04,   2.47585047e-03],
#        [ -4.66183790e-04,   2.45561988e-03]])

# %%
acc = npy.zeros((100,2))
for t in range(100):
#     acc[t,0] = math.cos(float(t)/31.42)/900
#     acc[t,1] = math.sin(float(t)/31.42)/900
    acc[t,0] = math.cos(float(t)/31.42)/900
    acc[t,1] = math.sin(float(t)/31.42)/900
    
vel = npy.zeros((100,2))
pos = npy.zeros((100,2))
dt=1
for t in range(1,100):
    vel[t] = vel[t-1]+acc[t]*dt
    
for t in range(1,100):
    pos[t] = pos[t-1]+vel[t]*dt #+acc[t]*(dt**2)
    
plt.plot(pos[:,0],pos[:,1])
# plt.plot(vel[:,0],vel[:,1])
# plt.plot(acc[:,0],acc[:,1])
plt.show()

# %%
with file('acceleration.npy','w') as outfile:
    npy.save(outfile,acc)
    
with file('velocity.npy','w') as outfile:
    npy.save(outfile,vel)
    
with file('position.npy','w') as outfile:
    npy.save(outfile,pos)

# %%
pos1 = npy.zeros((100,2))
for t in range(100):
    pos1[t,0] = math.cos(float(t)/20)
    pos1[t,1] = math.sin(float(t)/20)
plt.plot(pos1[:,0],pos1[:,1])    
plt.show()

# %%
vel1 = npy.zeros((100,2))

vel1[0:99] = npy.diff(pos1,axis=0)
acc1 = npy.zeros((100,2))
acc1[1:99] = npy.diff(pos1,axis=0,n=2)

# plt.plot(tr,vel1)
plt.plot(tr,acc1)
# plt.plot(vel1[:,0],vel1[:,1])
# plt.plot(acc1[:,0],acc1[:,1])
plt.show()

# %%
with file('acceleration1.npy','w') as outfile:
    npy.save(outfile,acc1)
    
with file('velocity1.npy','w') as outfile:
    npy.save(outfile,vel1)
    
with file('position1.npy','w') as outfile:
    npy.save(outfile,pos1)
